# %%
a = int(input())
b = int(input())
print(max(a, b))
# Out:
#  3
#  5
# 5

# %%
a = int(input())

if (a % 4 == 0 and a % 100 == 0) or (a % 400 == 0):
    print("YES")
else: 
    print("NO")
# Out:
#  500
# YES

# %%
a = int(input())
b = int(input())

if (a != 1 and b != 1 or a == b): 
    print("YES")
else:
    print("NO")
# Out:
#  4
#  4
# YES

# %%
a = int(input())
if a > 0:
    print(1)
elif a < 0:
    print(-1)
else:
    print(0)
# Out:
#  5
# 1

# %%
a = int(input())
b = int(input())
if a > b:
    print(1)
elif a < b:    
    print(2)
else:
    print(0)
    print(0)
# Out:
#  5
#  6
# 2
