# %%
import math

a = int(input())

i = 1

while i <= a:
    if int(math.sqrt(i)) == math.sqrt(i):
        print(i)
        i += 1
        continue
    i += 1
# Out:
#  9
# 1
# 4
# 9

# %%
a = int(input())

i = 2

while i <= a: 
    if a % i == 0:
        print(i)
        break
    i += 1
# Out:
#  7
# 7

# %%
import math

a = int(input())

i = 1

while i <= a:
    print(i)
    i *= 2
# Out:
#  17
# 1
# 2
# 4
# 8
# 16

# %%
a = int(input())

x = 1

while x < a:
    x *= 2
    
if x == a:
    print("YES")
else:
    print("NO")
# Out:
#  32
# YES

# %%
a = int(input())

i = 1
cnt = 0

while i < a:
    i *= 2
    cnt += 1

print(cnt)
# Out:
#  128
# 7
